# %%
import bs4
import requests

# %%
url = 'http://contracts.onecle.com/type/6.shtml'

# %%
r = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-5afaa71eb559> in <module>()
#       1 r = requests.get(url)
# ----> 2 r.status
#
# AttributeError: 'Response' object has no attribute 'status'

# %%
soup = bs4.BeautifulSoup(r.text, 'html.parser')

# %%
li = soup.find_all('li')

# %%
soup.find_all('a')
# Out:
# [<a href="http://www.onecle.com/"><img alt="onecle" height="37" id="logo-image" src="http://www.onecle.com/images/onecle-logo.jpg" width="150"/></a>,
#  <a href="http://www.onecle.com/" title="">Home</a>,
#  <a href="http://contracts.onecle.com/" title="Business Contracts">Business Contracts</a>,
#  <a href="http://law.onecle.com/" title="US Laws, Cases and Codes">Laws</a>,
#  <a href="http://contracts.onecle.com/consumer/incorporation.shtml" title="Corporation, LLC, LLP Forms">Incorporation</a>,
#  <a class="active-trail active" href="http://lawyers.onecle.com/" title="Lawyer Directory">Lawyer Directory</a>,
#  <a href="http://www.onecle.com/" itemprop="url"><span itemprop="title">Home</span></a>,
#  <a href="/index.shtml" itemprop="url"><span itemprop="title">Sample Business Contracts</span></a>,
#  <a href="/type/index.shtml"><span itemprop="title">By Contract Type</span></a>,
# ...
